# %% [markdown]
# <a href="https://colab.research.google.com/github/Adieva15/nn-training/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# обучаемый нейрон (перцептрон) для разделения
# двух классов точек на плоскости: C1 и C2.
import numpy as np
import matplotlib.pyplot as plt
N = 5
b = 3

x1 = np.random.random(N)
x2 = x1 + [np.random.randint(10)/10 for i in range(N)]+b

C1 = [x1, x2]

x1 = np.random.random(N)
x2 = x1 - [np.random.randint(10)/10 for i in range(N)] -0.1 + b
C2 = [x1, x2]

f = [0+b, 1+b]

w2 = 0/5
w3 = -b*w2
w = np.array([-w2, w2, w3])
for i in range(N):
  x = np.array([C1[0][i], C1[1][i], 1])
  y = np.dot(w, x)
  if y>=0:
    print("Класс C1")
  else:
    print("Класс C2")

plt.scatter(C1[0][:], C1[1][:], s=10, c='red')
plt.scatter(C2[0][:], C2[1][:], s=15, c='blue')
plt.plot(f)
plt.grid(True)
plt.show()
# Out:
# Класс C1
# Класс C1
# Класс C1
# Класс C1
# Класс C1

# %%
# 1
import numpy as np
import matplotlib.pyplot as plt

def act(x):
  return 0 if x < 0.5 else 1

def go(C):
  x = np.array([C[0], C[1], 1])
  w1= [1, 1, -1.5]
  w2= [1, 1, -0.5]
  w_hidden = np.array([w1, w2])
  w_out = np.array([-1, 1, -0.5])

  sum= np.dot(w_hidden, x) #вычисляем сумму на входах нейронов скрытого слоя
  print("Значения сумм на нейронах скрытого слоя: "+str(sum))

  out = [act(x) for x  in sum]
  print("Значения на выходах нейронов скрытого слоя: "+str(out))
  out.append(1)
  out = np.array(out)

  sum  = np.dot(w_out, out)
  y = act(sum)
  print("Выходное значение НС: "+str(y))

  return y

C1 = [(1,0),(0,1)]
C2=[(0,0),(1, 0)]

print(go(C1[0]), go(C1[1]))
print(go(C2[0]), go(C2[1]))
# Out:
# Значения сумм на нейронах скрытого слоя: [-0.5  0.5]
# Значения на выходах нейронов скрытого слоя: [0, 1]
# Выходное значение НС: 1
# Значения сумм на нейронах скрытого слоя: [-0.5  0.5]
# Значения на выходах нейронов скрытого слоя: [0, 1]
# Выходное значение НС: 1
# 1 1
# Значения сумм на нейронах скрытого слоя: [-1.5 -0.5]
# Значения на выходах нейронов скрытого слоя: [0, 0]
# Выходное значение НС: 0
# Значения сумм на нейронах скрытого слоя: [-0.5  0.5]
# Значения на выходах нейронов скрытого слоя: [0, 1]
# Выходное значение НС: 1
# 0 1
